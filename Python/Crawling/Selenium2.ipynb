# %%
import time   # sleep 지연
import os     # folder create 
import math   # ceil

from bs4 import BeautifulSoup      # Scraping(Crawling) package
from urllib.request import urlopen # 인터넷 접속후 페이지 소스 loading
from urllib.parse import quote     # 한글 처리 함수
from urllib.error import HTTPError # HTTP Exception
from requests import get           # GET 방식 호출

from selenium import webdriver  # 크롤링 이벤트 발생
driver = webdriver.Chrome('C:/kd/chromedriver.exe')

# 페이지 열기, second: 페이지가 local 컴퓨터에 모두 로딩될때까지 기다리는 시간
def load(url, second): 
    try:
        driver.get(url)
        time.sleep(second) # Web page loading을 기다림, 초단위, 0.5: 0.5초
    except HTTPError as e:
        print(e)
        return None
    
def getbs(): # bs 객체 생성
    try:
        bs = BeautifulSoup(driver.page_source, 'html.parser') 
    except HTTPError as e:
        print(e)
        return None
    else:
        return bs
# Out:
# C:\ProgramData\Anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   if sys.path[0] == '':

# %% [markdown]
# ### [01] 서울 날씨/온도의 수집
# - https://www.weather.go.kr/weather/observation/currentweather.jsp
# - 서울시의 관측위치, 기온 가져오기

# %%
load('https://www.weather.go.kr/weather/observation/currentweather.jsp', 2)

# %%
bs = getbs()
print(bs)
# Out:
# <html lang="ko"><head>
# <title>도시별관측 - 기상청 날씨누리</title>
# <meta charset="utf-8"/>
# <meta content="width=1551" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/w/iphone-shortcut.png" rel="shortcut icon"/>
# <link href="/w/iphone-shortcut.png" rel="apple-touch-icon-precomposed"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="https://www.weather.go.kr/w/iphone-shortcut.png" property="og:image"/>
# <link href="/w/resources/css-2021/slick.css?ver=2022021701" rel="stylesheet" type="text/css"/>
# <link href="/w/resources/css-2021/basic.css?ver=2022021701" rel="stylesheet" type="text/css"/>
# <link href="/w/resources/css-2021/common-ui.css?ver=2022021701" rel="stylesheet" type="text/css"/>
# <link href="/w/resources/css-2021/common-ui-mobile.css?ver=2022021701" rel="stylesheet" type="text/css"/>
# <link href="/w/resources/css-2021/custom.css?ver=2022021701" rel="stylesheet" type="text/css"/>
# ...

# %%
tag = bs.select('#weather_table > tbody > tr:nth-child(42) > td:nth-child(1) > a')[0]
print(tag.text)
# Out:
# 서울

# %%
tag = bs.select('#weather_table > tbody > tr:nth-child(42) > td:nth-child(2)')[0]
print(tag.text)
# Out:
# 비 끝

# %%
tag = bs.select('#weather_table > tbody > tr:nth-child(42) > td:nth-child(6)')[0]
print(tag.text)
# Out:
# 9.3
