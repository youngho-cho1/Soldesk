# %%
import time   # sleep 지연
import os     # folder create 
import math   # ceil

from bs4 import BeautifulSoup      # Scraping(Crawling) package
from urllib.request import urlopen # 인터넷 접속후 페이지 소스 loading
from urllib.parse import quote     # 한글 처리 함수
from urllib.error import HTTPError # HTTP Exception
from requests import get           # GET 방식 호출

from selenium import webdriver  # 크롤링 이벤트 발생
driver = webdriver.Chrome('C:/kd/chromedriver.exe')
driver.set_window_size(1280, 800)

# 페이지 열기, second: 페이지가 local 컴퓨터에 모두 로딩될때까지 기다리는 시간
def load(url, second): 
    try:
        driver.get(url)
        time.sleep(second) # Web page loading을 기다림, 초단위, 0.5: 0.5초
    except HTTPError as e:
        print(e)
        return None
    
def getbs(): # bs 객체 생성
    try:
        bs = BeautifulSoup(driver.page_source, 'html.parser') 
    except HTTPError as e:
        print(e)
        return None
    else:
        return bs
# Out:
# C:\ProgramData\Anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   if sys.path[0] == '':

# %% [markdown]
# ### AWS 관측 장비를 이용한 대관령 날씨 정보 수집
# - https://www.weather.go.kr/weather/observation/aws_table_popup.jsp

# %%
load('https://www.weather.go.kr/w/index.do', 2)

# %%
bs = getbs()
print(bs)
# Out:
# <html lang="ko"><head>
# <title>홈 - 기상청 날씨누리</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=1551" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/w/iphone-shortcut.png" rel="shortcut icon"/>
# <link href="/w/iphone-shortcut.png" rel="apple-touch-icon-precomposed"/>
# <meta content="기상청 날씨누리" property="og:title"/>
# <meta content="기상청 날씨누리" property="og:description"/>
# <meta content="https://www.weather.go.kr/w/iphone-shortcut.png" property="og:image"/>
# <link href="/w/resources/css-2021/slick.css?ver=2022021701" rel="stylesheet" type="text/css"/>
# <link href="/w/resources/css-2021/basic.css?ver=2022021701" rel="stylesheet" type="text/css"/>
# <link href="/w/resources/css-2021/common-ui.css?ver=2022021701" rel="stylesheet" type="text/css"/>
# <link href="/w/resources/css-2021/common-ui-mobile.css?ver=2022021701" rel="stylesheet" type="text/css"/>
# ...

# %%
# 대관령 click event 발생
# #map > div.ol-viewport > div.ol-overlaycontainer-stopevent > div:nth-child(113)
driver.find_element_by_css_selector('#map > div.ol-viewport > div.ol-overlaycontainer-stopevent > div:nth-child(112) > div > span:nth-child(1) > img') .click()
# Out:
# C:\ProgramData\Anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4600\3485658512.py in <module>
#       1 # 대관령 click event 발생
#       2 # #map > div.ol-viewport > div.ol-overlaycontainer-stopevent > div:nth-child(112) > div > span:nth-child(1) > img
# ----> 3 driver.find_element_by_css_selector('#map > div.ol-viewport > div.ol-overlaycontainer-stopevent > div:nth-child(112) > div > span:nth-child(1) > img') .click()
#
# C:\ProgramData\Anaconda3\envs\ai\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
# ...

# %%
#daumHead > div.d_service > div > div.today_base > div > div > a > ul > li:nth-child(1) > strong
tag = bs.select('#daumHead > div.d_service > div > div.today_base > div > div > a > ul > li:nth-child(1) > strong')[0]
print(tag.text)
# Out:
# 비

# %%
#daumHead > div.d_service > div > div.today_base > div > div > a > ul > li:nth-child(1) > span.txt_temper
tag = bs.select('#daumHead > div.d_service > div > div.today_base > div > div > a > ul > li:nth-child(1) > span.txt_temper')[0]
print(tag.text)
# Out:
# 10
